# %%
import os
import numpy as np
import pandas as pd
from tqdm import tqdm
import matplotlib.pyplot as plt

from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.preprocessing import StandardScaler

from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Dropout, GlobalAveragePooling2D, Concatenate
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

# %%
IMG_SIZE = (96,96)
IMAGE_DIR = "train_images"
TARGET_COLS = ["X4_mean", "X11_mean", "X18_mean", "X26_mean", "X50_mean", "X3112_mean"]

# %%
train_df = pd.read_csv("train.csv")

# %%
X_tab_raw = train_df.drop(columns=["id"]).iloc[:, :-6]
Q1 = X_tab_raw.quantile(0.25)
Q3 = X_tab_raw.quantile(0.75)
IQR = Q3 - Q1

outlier_mask = (X_tab_raw < (Q1 - 1.5 * IQR)) | (X_tab_raw > (Q3 + 1.5 * IQR))
outlier_count = outlier_mask.sum(axis=1)

mask = outlier_count <= 10

X_tab_raw = X_tab_raw[mask]
train_df = train_df[mask] 

y = train_df[TARGET_COLS].values

y_scaler = StandardScaler()
y_scaled = y_scaler.fit_transform(y)

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_tab_raw)

pca = PCA(n_components=20)
X_pca = pca.fit_transform(X_scaled)
print(f"Total de varianza explicada por los 20 componentes: {pca.explained_variance_ratio_.sum():.4f}")
print(f"Total de instancias para entrenamiento: {len(train_df)}")
# Out:
# Total de varianza explicada por los 20 componentes: 0.9246
# Total de instancias para entrenamiento: 42807

# %%
def load_and_process_image(img_id):
    img_path = os.path.join(IMAGE_DIR, f"{img_id}.jpg")
    if not os.path.exists(img_path):
        img_path = os.path.join(IMAGE_DIR, f"{img_id}.png")
    if not os.path.exists(img_path):
        img_path = os.path.join(IMAGE_DIR, f"{img_id}.jpeg")
    img = load_img(img_path, target_size=IMG_SIZE)
    img = img_to_array(img)
    return preprocess_input(img)

image_array = np.array([load_and_process_image(i) for i in tqdm(train_df['id'], desc="Cargando imágenes")])
# Out:
# Cargando imágenes: 100%|█████████████████████████████████████████████████████████████████████████████████████████████| 42807/42807 [02:46<00:00, 257.18it/s]

# %%
def build_model(img_shape, tab_shape, output_dim):
    # Imagen
    img_input = Input(shape=img_shape)
    base_cnn = MobileNetV2(include_top=False, weights='imagenet', input_shape=img_shape)
    base_cnn.trainable = True  # Fine-tune
    x_img = base_cnn(img_input)
    x_img = GlobalAveragePooling2D()(x_img)

    # Tabular
    tab_input = Input(shape=(tab_shape,))
    x_tab = Dense(128, activation='relu')(tab_input)
    x_tab = Dropout(0.3)(x_tab)

    # Concatenación
    x = Concatenate()([x_img, x_tab])
    x = Dense(128, activation='relu')(x)
    x = Dropout(0.3)(x)
    output = Dense(output_dim)(x)

    model = Model(inputs=[img_input, tab_input], outputs=output)
    return model

model = build_model((96, 96, 3), X_pca.shape[1], y_scaled.shape[1])
model.compile(optimizer=Adam(1e-5), loss='mse', metrics=['root_mean_squared_error'])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_96_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
X_img_train, X_img_val, X_tab_train, X_tab_val, y_train, y_val = train_test_split(
    image_array, X_pca, y_scaled, test_size=0.2, random_state=42)


history = model.fit(
    [X_img_train, X_tab_train], y_train,
    validation_data=([X_img_val, X_tab_val], y_val),
    epochs=15,
    batch_size=32,
    callbacks=[EarlyStopping(patience=3, restore_best_weights=True)],
    verbose=1
)
# Out:
# Epoch 1/15
# 1071/1071 ━━━━━━━━━━━━━━━━━━━━ 364s 320ms/step - loss: 1.8459 - root_mean_squared_error: 1.3513 - val_loss: 1.7356 - val_root_mean_squared_error: 1.3174
# Epoch 2/15
# 1071/1071 ━━━━━━━━━━━━━━━━━━━━ 334s 312ms/step - loss: 0.8134 - root_mean_squared_error: 0.8891 - val_loss: 1.6430 - val_root_mean_squared_error: 1.2818
# Epoch 3/15
# 1071/1071 ━━━━━━━━━━━━━━━━━━━━ 331s 309ms/step - loss: 0.5950 - root_mean_squared_error: 0.7517 - val_loss: 1.6214 - val_root_mean_squared_error: 1.2733
# Epoch 4/15
# 1071/1071 ━━━━━━━━━━━━━━━━━━━━ 332s 310ms/step - loss: 0.6754 - root_mean_squared_error: 0.8141 - val_loss: 1.6090 - val_root_mean_squared_error: 1.2685
# Epoch 5/15
# 1071/1071 ━━━━━━━━━━━━━━━━━━━━ 340s 318ms/step - loss: 0.8628 - root_mean_squared_error: 0.9192 - val_loss: 1.5996 - val_root_mean_squared_error: 1.2648
# Epoch 6/15
# 1071/1071 ━━━━━━━━━━━━━━━━━━━━ 329s 307ms/step - loss: 0.5251 - root_mean_squared_error: 0.7101 - val_loss: 1.5907 - val_root_mean_squared_error: 1.2612
# Epoch 7/15
# 1071/1071 ━━━━━━━━━━━━━━━━━━━━ 326s 305ms/step - loss: 0.9812 - root_mean_squared_error: 0.9790 - val_loss: 1.5807 - val_root_mean_squared_error: 1.2573
# Epoch 8/15
# 1071/1071 ━━━━━━━━━━━━━━━━━━━━ 330s 308ms/step - loss: 0.6067 - root_mean_squared_error: 0.7703 - val_loss: 1.5711 - val_root_mean_squared_error: 1.2534
# Epoch 9/15
# 1071/1071 ━━━━━━━━━━━━━━━━━━━━ 347s 324ms/step - loss: 0.5003 - root_mean_squared_error: 0.6987 - val_loss: 1.5616 - val_root_mean_squared_error: 1.2496
# Epoch 10/15
# 1071/1071 ━━━━━━━━━━━━━━━━━━━━ 357s 333ms/step - loss: 0.6899 - root_mean_squared_error: 0.7698 - val_loss: 1.5566 - val_root_mean_squared_error: 1.2476
# Epoch 11/15
# 1071/1071 ━━━━━━━━━━━━━━━━━━━━ 351s 328ms/step - loss: 0.5615 - root_mean_squared_error: 0.7307 - val_loss: 1.5524 - val_root_mean_squared_error: 1.2460
# Epoch 12/15
# 1071/1071 ━━━━━━━━━━━━━━━━━━━━ 359s 335ms/step - loss: 0.5019 - root_mean_squared_error: 0.7012 - val_loss: 1.5439 - val_root_mean_squared_error: 1.2425
# Epoch 13/15
# 1071/1071 ━━━━━━━━━━━━━━━━━━━━ 356s 332ms/step - loss: 0.5690 - root_mean_squared_error: 0.7454 - val_loss: 1.5367 - val_root_mean_squared_error: 1.2396
# Epoch 14/15
# 1071/1071 ━━━━━━━━━━━━━━━━━━━━ 361s 337ms/step - loss: 0.3455 - root_mean_squared_error: 0.5771 - val_loss: 1.5373 - val_root_mean_squared_error: 1.2399
# Epoch 15/15
# 1071/1071 ━━━━━━━━━━━━━━━━━━━━ 363s 339ms/step - loss: 0.2802 - root_mean_squared_error: 0.5256 - val_loss: 1.5298 - val_root_mean_squared_error: 1.2369

# %%
y_pred_val = model.predict([X_img_val, X_tab_val])
y_pred_val_real = y_scaler.inverse_transform(y_pred_val)
y_val_real = y_scaler.inverse_transform(y_val)


print("\nR² por variable:")
for i, col in enumerate(TARGET_COLS):
    r2 = r2_score(y_val_real[:, i], y_pred_val_real[:, i])
    print(f"{col}: {r2:.4f}")
# Out:
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 18s 62ms/step
#
# R² por variable:
# X4_mean: 0.1296
# X11_mean: -168.7722
# X18_mean: 0.2817
# X26_mean: -47.7181
# X50_mean: 0.0597
# X3112_mean: 0.0269

# %%
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title("Evolución de la pérdida")
plt.xlabel("Época")
plt.ylabel("MSE")
plt.legend()
plt.grid()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Copias para conservar datos originales
y_val_real_filt = y_val_real.copy()
y_pred_val_real_filt = y_pred_val_real.copy()

# Filtrado por percentiles 5%-95% para cada variable
mask_global = np.ones(len(y_val_real), dtype=bool)
for i in range(y_val_real.shape[1]):
    # Determinar los percentiles para los valores reales
    p5_real, p95_real = np.percentile(y_val_real[:, i], [5, 95])
    # Determinar los percentiles para las predicciones
    p5_pred, p95_pred = np.percentile(y_pred_val_real[:, i], [5, 95])

    # Crear una máscara booleana combinada (ambos dentro de rango)
    mask_i = (
        (y_val_real[:, i] >= p5_real) & (y_val_real[:, i] <= p95_real) &
        (y_pred_val_real[:, i] >= p5_pred) & (y_pred_val_real[:, i] <= p95_pred)
    )

    # Combinar con la máscara global (conserva solo los puntos válidos en todas las columnas)
    mask_global &= mask_i

# Aplicar la máscara global
y_val_real_filt = y_val_real[mask_global]
y_pred_val_real_filt = y_pred_val_real[mask_global]

# Graficar los datos filtrados
fig, axs = plt.subplots(2, 3, figsize=(15, 8))
for i, ax in enumerate(axs.flat):
    ax.scatter(y_val_real_filt[:, i], y_pred_val_real_filt[:, i], alpha=0.3)
    ax.plot([min(y_val_real_filt[:, i]), max(y_val_real_filt[:, i])],
            [min(y_val_real_filt[:, i]), max(y_val_real_filt[:, i])], 'r--')
    ax.set_title(f'{TARGET_COLS[i]}')
    ax.set_xlabel('Real')
    ax.set_ylabel('Predicción')
plt.tight_layout()
plt.show()

# %%
test_df = pd.read_csv("test.csv")
# Usar las mismas columnas que en X_tab_raw
X_test_tab = test_df[X_tab_raw.columns]
X_test_tab_scaled = scaler.transform(X_test_tab)
X_test_tab_pca = pca.transform(X_test_tab_scaled)

# %%
test_df = pd.read_csv("test.csv")
X_test_tab = test_df[X_tab_raw.columns]
X_test_tab_scaled = scaler.transform(X_test_tab)
X_test_tab_pca = pca.transform(X_test_tab_scaled)

def load_and_process_test_image(img_id):
    n = 0
    for ext in ['.jpg', '.png', '.jpeg']:
        img_path = os.path.join("test_images", f"{img_id}{ext}")
        if os.path.exists(img_path):
            img = load_img(img_path, target_size=IMG_SIZE)
            img = img_to_array(img)
            return preprocess_input(img)
        n += 1
    print(f"Imagenes no encontradas: {n}")

X_test_img = []
valid_ids = []

for img_id in tqdm(test_df['id'], desc="Cargando imágenes de test"):
    img = load_and_process_test_image(img_id)
    if img is not None:
        X_test_img.append(img)
        valid_ids.append(img_id)

X_test_img = np.array(X_test_img)
test_df = test_df[test_df['id'].isin(valid_ids)].reset_index(drop=True)
X_test_tab_pca = X_test_tab_pca[test_df.index]
# Out:
# Cargando imágenes de test:  28%|████████████████████████▏                                                              | 1817/6545 [00:05<00:13, 348.94it/s]
# Imagenes no encontradas: 3
# Cargando imágenes de test: 100%|███████████████████████████████████████████████████████████████████████████████████████| 6545/6545 [00:18<00:00, 345.12it/s]

# %%
y_test_pred = model.predict([X_test_img, X_test_tab_pca])

output_df = pd.DataFrame(y_test_pred, columns=TARGET_COLS)
output_df.insert(0, 'id', test_df['id'])
output_df.to_csv('predicciones_test.csv', index=False)
# Out:
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step
